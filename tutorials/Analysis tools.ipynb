# %% [markdown]
# # Analysis tools

# %% [markdown]
# Swan has several analysis options to use.
# * [Differential expression tests](#de)
# * [Isoform switching / differential isoform expression](#is)
# * [Combining metadata columns](#multi_gb)
# * [Exon skipping and intron retention](#es_ir)
# * [More differential expression](#more_de)
#
# <!-- Running this tutorial on my laptop took around 30 minutes and 3 GB of RAM. The longest steps by far are running the differential gene and transcript expression tools. The diffxpy tools are multithreaded, and my laptop has 8 cores. -->

# %%
import swan_vis as swan

sg = swan.read('data/swan.p')
# Out:
# Read in graph from data/swan.p

# %% [markdown]
# ## <a name="de"></a>Differential expression tests

# %% [markdown]
# Swan's old differential gene and transcript expression tests using `diffxpy` have now been deprecated as it seems that the library is unsupported. I recommend that users interested in running differential gene or transcript expression test either use [PyDESeq2](https://github.com/owkin/PyDESeq2) or Scanpy's [`rank_genes_groups`](https://scanpy.readthedocs.io/en/stable/generated/scanpy.tl.rank_genes_groups.html) test, which both support the AnnData format for simple compatibility with Swan's AnnData expression representation.

# %% [markdown]
# <!-- ### <a name="de"></a>Using Scanpy's `rank_genes_groups` -->

# %% [markdown]
# <!-- `rank_genes_groups` expects logarithmized data, so make sure you transform your data before running the test on whichever [AnnData](https://freese.gitbook.io/swan/faqs/data_structure#anndata) you want that's in your SwanGraph. -->

# %% [markdown]
# <!-- ```python
# import scanpy as sc
#
# sg.adata.X = sg.adata.layers['tpm']
# sc.pp.log1p(sg.adata)
# sg.adata.layers['log_norm'] = sg.adata.X.copy()
# sc.tl.rank_genes_groups(sg.adata,
#                         groupby=<obs_col>,
#                         groups=<obs_conditions>,
#                         layer='log_norm',
#                         method='wilcoxon')
#
# results_df = sc.get.rank_genes_groups_df(sg.adata, <obs_condition>)
# results_df.head()
# ``` -->

# %% [markdown]
# ### <a name="de"></a>Using PyDESeq2

# %% [markdown]
# Please read the [PyDESeq2 documentation](https://pydeseq2.readthedocs.io/en/latest/) for details on how to use one of the SwanGraph AnnData objects to obtain differential expression results. Below is an example on how to find differentially expressed transcripts between cell lines.

# %%
from pydeseq2.dds import DeseqDataSet
from pydeseq2.ds import DeseqStats
import numpy as np

adata = sg.adata.copy()

# PyDESeq2 currently doesn't support column names with underscores, so change that
adata.obs.rename({'cell_line': 'cellline'}, axis=1, inplace=True)
obs_col = 'cellline'

threads = 8

# densify matrix
adata.X = np.array(adata.X.todense())

# run test
dds = DeseqDataSet(adata=adata,
               design_factors=obs_col,
               n_cpus=threads,
               refit_cooks=True)
dds.deseq2()
stat_res = DeseqStats(dds,
                  n_cpus=threads)
stat_res.summary()

df = stat_res.results_df
# Out:
# Fitting size factors...
# ... done in 0.00 seconds.
#
# Fitting dispersions...
# ... done in 34.09 seconds.
#
# Fitting dispersion trend curve...
# ... done in 12.01 seconds.
#
# Fitting MAP dispersions...
# ... done in 13.97 seconds.
#
# Fitting LFCs...
# ... done in 4.86 seconds.
#
# Refitting 0 outliers.
#
# Running Wald tests...
# ... done in 2.36 seconds.
#
# Log2 fold change & Wald test p-value: cellline hffc6 vs hepg2
#                    baseMean  log2FoldChange     lfcSE      stat    pvalue
# tid
# TALONT000296400    3.497574        2.416436  1.472616  1.640914  0.100815  \
# ENST00000591581.1  0.162115        0.624956  5.002765  0.124922  0.900585
# ENST00000546893.5  8.173445       -0.053334  0.793179 -0.067241  0.946390
# ENST00000537289.1  5.140216       -1.248175  0.978927 -1.275044  0.202294
# ENST00000258382.9  2.012104       -0.011819  1.493866 -0.007912  0.993687
# ...                     ...             ...       ...       ...       ...
# ENST00000506914.1  1.022692        0.947588  2.272813  0.416923  0.676735
# ENST00000571080.1  0.473263       -2.824409  3.426473 -0.824291  0.409774
# ENST00000378615.7  1.334873       -1.199810  1.790781 -0.669993  0.502862
# ENST00000409586.7  0.338615        1.464364  4.023896  0.363917  0.715920
# ENST00000370278.3  1.328549       -1.201246  1.962358 -0.612144  0.540443
#
#                        padj
# tid
# TALONT000296400    0.193840
# ENST00000591581.1       NaN
# ENST00000546893.5  0.968527
# ENST00000537289.1  0.328286
# ENST00000258382.9       NaN
# ...                     ...
# ENST00000506914.1       NaN
# ENST00000571080.1       NaN
# ENST00000378615.7       NaN
# ENST00000409586.7       NaN
# ENST00000370278.3       NaN
#
# [34814 rows x 6 columns]

# %%
df.head()
# Out:
#                    baseMean  log2FoldChange     lfcSE      stat    pvalue
# tid
# TALONT000296400    3.497574        2.416436  1.472616  1.640914  0.100815  \
# ENST00000591581.1  0.162115        0.624956  5.002765  0.124922  0.900585
# ENST00000546893.5  8.173445       -0.053334  0.793179 -0.067241  0.946390
# ENST00000537289.1  5.140216       -1.248175  0.978927 -1.275044  0.202294
# ENST00000258382.9  2.012104       -0.011819  1.493866 -0.007912  0.993687
#
#                        padj
# tid
# TALONT000296400    0.193840
# ENST00000591581.1       NaN
# ENST00000546893.5  0.968527
# ENST00000537289.1  0.328286
# ENST00000258382.9       NaN

# %% [markdown]
# ## <a name="is"></a>Isoform switching / Differential isoform expression testing

# %% [markdown]
# Isoform switching / differential isoform expression (DIE) testing is implemented according to the strategy in [Joglekar et. al., 2021](https://www.nature.com/articles/s41467-020-20343-5). DIE can roughly be described as finding statistically significant changes in isoform expression between two conditions along with a change in percent isoform usage per gene.
#
# Pairwise comparisons can be set up using different columns in the metadata that was added to the SwanGraph with the `obs_col` and `obs_conditions` arguments.

# %%
# look at valid metadata options
sg.adata.obs
# Out:
#         cell_line replicate  dataset  total_counts
# dataset
# hepg2_1     hepg2         1  hepg2_1      499647.0
# hepg2_2     hepg2         2  hepg2_2      848447.0
# hffc6_1     hffc6         1  hffc6_1      761493.0
# hffc6_2     hffc6         2  hffc6_2      787967.0
# hffc6_3     hffc6         3  hffc6_3      614921.0

# %%
# find genes that exhibit DIE between HFFc6 and HepG2
obs_col = 'cell_line'
obs_conditions = ['hepg2', 'hffc6']
die_table, die_results = sg.die_gene_test(obs_col=obs_col, 
                                          obs_conditions=obs_conditions,
                                          verbose=True)
# Out:
# Testing for DIE for each gene: 100%|██████████| 14684/14684 [03:50<00:00, 123.69it/s]

# %% [markdown]
# The resultant table contains an entry for each gene with the p value (`p_val`), adjusted p value (`adj_p_val`), and change in percent isoform usage for the top two isoforms (`dpi`), as well as the identities of the top isoforms involved in the switch. Exact details on these calculations can be found in [Joglekar et. al., 2021](https://www.nature.com/articles/s41467-020-20343-5).

# %%
die_table.head()
# Out:
#                gid     p_val        dpi          pos_iso_1          pos_iso_2  \
# 0  ENSG00000130175  0.206667  39.264992    TALONT000296399                NaN
# 1  ENSG00000130202  0.000367  11.893251  ENST00000252485.8  ENST00000252483.9
# 2  ENSG00000111371  0.680435   9.401713  ENST00000398637.9  ENST00000439706.5
# 3  ENSG00000181924  0.028195   9.452934  ENST00000537289.1  ENST00000545127.1
# 4  ENSG00000163468  0.255788   0.680048  ENST00000295688.7    TALONT000476055
#
#    pos_iso_1_dpi  pos_iso_2_dpi          neg_iso_1          neg_iso_2  \
# 0      39.264992            NaN    TALONT000296400  ENST00000589838.5
# 1       9.684967       2.208281    TALONT000406668  ENST00000591581.1
# 2       8.547012       0.854701  ENST00000546893.5                NaN
# 3       7.298603       2.154328  ENST00000355693.4                NaN
# 4       0.366966       0.277693  ENST00000368259.6  ENST00000489870.1
#
#    neg_iso_1_dpi  neg_iso_2_dpi  adj_p_val    gname
# 0     -20.116056     -10.638298   0.469420   PRKCSH
# 1     -11.473083      -0.420168   0.003560  NECTIN2
# 2      -9.401711            NaN   0.886243  SLC38A1
# 3      -9.452934            NaN   0.122619     COA4
# 4      -0.568503      -0.111545   0.525066     CCT3

# %% [markdown]
# Differential isoform expression testing results are stored automatically in `sg.adata.uns`, and will be saved to the SwanGraph if you save it. You can regenerate this key and access the summary table by running the following code:

# %%
# die_iso - isoform level differential isoform expression test results
uns_key = swan.make_uns_key('die',
                            obs_col=obs_col, 
                            obs_conditions=obs_conditions)
test = sg.adata.uns[uns_key]
test.head(2)
# Out:
#                gid     p_val        dpi          pos_iso_1          pos_iso_2  \
# 0  ENSG00000130175  0.206667  39.264992    TALONT000296399                NaN
# 1  ENSG00000130202  0.000367  11.893251  ENST00000252485.8  ENST00000252483.9
#
#    pos_iso_1_dpi  pos_iso_2_dpi        neg_iso_1          neg_iso_2  \
# 0      39.264992            NaN  TALONT000296400  ENST00000589838.5
# 1       9.684967       2.208281  TALONT000406668  ENST00000591581.1
#
#    neg_iso_1_dpi  neg_iso_2_dpi  adj_p_val    gname
# 0     -20.116056     -10.638298    0.46942   PRKCSH
# 1     -11.473083      -0.420168    0.00356  NECTIN2

# %% [markdown]
# Swan comes with an easy way to filter your DIE test results based on adjusted p value and dpi thresholds.

# %%
test = sg.get_die_genes(obs_col=obs_col, obs_conditions=obs_conditions,
                       p=0.05, dpi=10)
test.head()
# Out:
#                 gid          p_val        dpi          pos_iso_1  \
# 1   ENSG00000130202   3.674234e-04  11.893251  ENST00000252485.8
# 8   ENSG00000025156   1.857411e-03  35.714287  ENST00000452194.5
# 20  ENSG00000105254   4.779408e-38  25.419458  ENST00000585910.5
# 23  ENSG00000105379  1.802782e-307  81.136333  ENST00000354232.8
# 28  ENSG00000148180   0.000000e+00  89.319039  ENST00000373818.8
#
#             pos_iso_2  pos_iso_1_dpi  pos_iso_2_dpi          neg_iso_1  \
# 1   ENST00000252483.9       9.684967       2.208281    TALONT000406668
# 8   ENST00000465214.2      25.714287      10.000000  ENST00000368455.8
# 20    TALONT000366329      20.394853       4.702971  ENST00000221855.7
# 23                NaN      81.136333            NaN  ENST00000309244.8
# 28    TALONT000419680      85.245850       4.073189    TALONT000418752
#
#             neg_iso_2  neg_iso_1_dpi  neg_iso_2_dpi      adj_p_val    gname
# 1   ENST00000591581.1     -11.473083      -0.420168   3.560035e-03  NECTIN2
# 8                 NaN     -35.714287            NaN   1.405048e-02     HSF2
# 20  ENST00000589996.5     -25.016304      -0.403154   7.343219e-36     TBCB
# 23  ENST00000596253.1     -80.857935      -0.278394  1.551113e-304     ETFB
# 28  ENST00000373808.8     -68.603180      -7.768958   0.000000e+00      GSN

# %% [markdown]
# Swan also now automatically tracks transcription start site (TSS) and transcription end site (TES) usage, and can find genes that exhibit DIE on the basis of their starts or ends. To do this, use the `kind` argument to `die_gene_test`.

# %%
# find genes that exhibit DIE for TSSs between HFFc6 and HepG2
die_table, die_results = sg.die_gene_test(kind='tss', 
                                          obs_col=obs_col,
                                          obs_conditions=obs_conditions,
                                          verbose=True)
die_table.head()
# Out:
# Testing for DIE for each gene: 100%|██████████| 14684/14684 [05:38<00:00, 43.42it/s]
# Testing for DIE for each gene: 100%|█████████▉| 14674/14684 [02:18<00:00, 162.60it/s]
#                gid     p_val        dpi          pos_iso_1          pos_iso_2  \
# 0  ENSG00000000419  0.249561  10.002187  ENSG00000000419_2  ENSG00000000419_1
# 1  ENSG00000001461  0.852914   9.093739  ENSG00000001461_5                NaN
# 2  ENSG00000001497  0.891496   3.846153  ENSG00000001497_1                NaN
# 3  ENSG00000001630  0.286866   2.580168  ENSG00000001630_3                NaN
# 4  ENSG00000002330  0.184635  12.817431  ENSG00000002330_2  ENSG00000002330_1
#
#    pos_iso_1_dpi  pos_iso_2_dpi          neg_iso_1          neg_iso_2  \
# 0       9.906052       0.096133  ENSG00000000419_3  ENSG00000000419_4
# 1       9.093739            NaN  ENSG00000001461_1  ENSG00000001461_3
# 2       3.846146            NaN  ENSG00000001497_2                NaN
# 3       2.580168            NaN  ENSG00000001630_2  ENSG00000001630_1
# 4      11.868484       0.948944  ENSG00000002330_4  ENSG00000002330_3
#
#    neg_iso_1_dpi  neg_iso_2_dpi  adj_p_val    gname
# 0      -7.218704      -2.783483   0.536906     DPM1
# 1      -5.543442      -1.775148   1.000000   NIPAL3
# 2      -3.846153            NaN   1.000000    LAS1L
# 3      -1.549232      -1.030928   0.582636  CYP51A1
# 4     -12.603584      -0.213847   0.454053      BAD

# %% [markdown]
# To access the die results on the tss level, use `die_kind='tss'` as input to `make_uns_key()`.

# %%
# die_iso - TSS level differential isoform expression test results
uns_key = swan.make_uns_key('die',
                            obs_col=obs_col, 
                            obs_conditions=obs_conditions,
                            die_kind='tss')
test = sg.adata.uns[uns_key]
test.head(2)
# Out:
#                gid     p_val        dpi          pos_iso_1          pos_iso_2  \
# 0  ENSG00000000419  0.249561  10.002187  ENSG00000000419_2  ENSG00000000419_1
# 1  ENSG00000001461  0.852914   9.093739  ENSG00000001461_5                NaN
#
#    pos_iso_1_dpi  pos_iso_2_dpi          neg_iso_1          neg_iso_2  \
# 0       9.906052       0.096133  ENSG00000000419_3  ENSG00000000419_4
# 1       9.093739            NaN  ENSG00000001461_1  ENSG00000001461_3
#
#    neg_iso_1_dpi  neg_iso_2_dpi  adj_p_val   gname
# 0      -7.218704      -2.783483   0.536906    DPM1
# 1      -5.543442      -1.775148   1.000000  NIPAL3

# %% [markdown]
# And provide the `kind='tss'` option to `get_die_genes()` when trying to filter your test results.

# %%
test = sg.get_die_genes(kind='tss', obs_col=obs_col, 
                        obs_conditions=obs_conditions,
                        p=0.05, dpi=10)
test.head()
# Out:
#                 gid         p_val        dpi          pos_iso_1  \
# 10  ENSG00000003402  7.338098e-15  84.848486  ENSG00000003402_3
# 11  ENSG00000003436  3.812087e-06  34.072281  ENSG00000003436_1
# 16  ENSG00000004487  1.135407e-03  75.714287  ENSG00000004487_1
# 33  ENSG00000006282  4.544048e-03  19.819595  ENSG00000006282_2
# 43  ENSG00000007376  1.256379e-04  27.898551  ENSG00000007376_3
#
#             pos_iso_2  pos_iso_1_dpi  pos_iso_2_dpi          neg_iso_1  \
# 10  ENSG00000003402_7      77.272728       7.575758  ENSG00000003402_1
# 11  ENSG00000003436_3      28.073771       4.564083  ENSG00000003436_4
# 16                NaN      75.714287            NaN  ENSG00000004487_2
# 33  ENSG00000006282_1      13.679245       6.140350  ENSG00000006282_3
# 43  ENSG00000007376_1      23.454107       4.444445  ENSG00000007376_5
#
#             neg_iso_2  neg_iso_1_dpi  neg_iso_2_dpi     adj_p_val    gname
# 10  ENSG00000003402_5     -31.717173     -22.222223  4.390279e-13    CFLAR
# 11                NaN     -34.072281            NaN  7.064168e-05     TFPI
# 16                NaN     -75.714285            NaN  1.020405e-02    KDM1A
# 33                NaN     -19.819595            NaN  3.236475e-02  SPATA20
# 43  ENSG00000007376_7     -14.130434      -7.512077  1.525134e-03   RPUSD1

# %% [markdown]
# For TESs, use `kind='tes'` as input to `die_genes_test()`, `die_kind='tes'` to `make_uns_key()`, and `kind='tes'` to `get_die_genes()`.

# %%
# find genes that exhibit DIE for TESs between HFFc6 and HepG2
die_table, die_results = sg.die_gene_test(kind='tes',
                                          obs_col='cell_line',
                                          obs_conditions=['hepg2', 'hffc6'])
die_table.head()
# Out:
# Testing for DIE for each gene: 100%|██████████| 14684/14684 [02:19<00:00, 105.51it/s]
#                gid     p_val        dpi          pos_iso_1          pos_iso_2  \
# 0  ENSG00000000419  1.000000   0.096133  ENSG00000000419_2                NaN
# 1  ENSG00000001461  0.852914   9.093739  ENSG00000001461_3                NaN
# 2  ENSG00000001630  0.286866   2.580168  ENSG00000001630_2                NaN
# 3  ENSG00000002330  0.184635  12.817431  ENSG00000002330_1  ENSG00000002330_4
# 4  ENSG00000002549  0.679148   0.694543  ENSG00000002549_2                NaN
#
#    pos_iso_1_dpi  pos_iso_2_dpi          neg_iso_1          neg_iso_2  \
# 0       0.096133            NaN  ENSG00000000419_1                NaN
# 1       9.093739            NaN  ENSG00000001461_4  ENSG00000001461_1
# 2       2.580168            NaN  ENSG00000001630_1  ENSG00000001630_3
# 3      11.868484       0.948944  ENSG00000002330_2  ENSG00000002330_3
# 4       0.694542            NaN  ENSG00000002549_1                NaN
#
#    neg_iso_1_dpi  neg_iso_2_dpi  adj_p_val    gname
# 0      -0.096130            NaN   1.000000     DPM1
# 1      -5.543442      -1.775148   1.000000   NIPAL3
# 2      -1.549232      -1.030928   0.618077  CYP51A1
# 3     -12.603584      -0.213847   0.480860      BAD
# 4      -0.694543            NaN   0.926889     LAP3

# %%
# die_iso - TES level differential isoform expression test results
uns_key = swan.make_uns_key('die',
                            obs_col=obs_col, 
                            obs_conditions=obs_conditions,
                            die_kind='tes')
test = sg.adata.uns[uns_key]
test.head(2)
# Out:
#                gid     p_val       dpi          pos_iso_1 pos_iso_2  \
# 0  ENSG00000000419  1.000000  0.096133  ENSG00000000419_2       NaN
# 1  ENSG00000001461  0.852914  9.093739  ENSG00000001461_3       NaN
#
#    pos_iso_1_dpi  pos_iso_2_dpi          neg_iso_1          neg_iso_2  \
# 0       0.096133            NaN  ENSG00000000419_1                NaN
# 1       9.093739            NaN  ENSG00000001461_4  ENSG00000001461_1
#
#    neg_iso_1_dpi  neg_iso_2_dpi  adj_p_val   gname
# 0      -0.096130            NaN        1.0    DPM1
# 1      -5.543442      -1.775148        1.0  NIPAL3

# %%
test = sg.get_die_genes(kind='tes', obs_col=obs_col, 
                        obs_conditions=obs_conditions,
                        p=0.05, dpi=10)
test.head()
# Out:
#                 gid         p_val        dpi          pos_iso_1  \
# 9   ENSG00000003402  7.338098e-15  84.848486  ENSG00000003402_5
# 10  ENSG00000003436  2.772096e-07  32.637854  ENSG00000003436_1
# 14  ENSG00000004487  1.135407e-03  75.714287  ENSG00000004487_2
# 32  ENSG00000006282  6.858641e-03  19.819595  ENSG00000006282_2
# 60  ENSG00000010278  3.191221e-22  39.024387  ENSG00000010278_2
#
#             pos_iso_2  pos_iso_1_dpi  pos_iso_2_dpi          neg_iso_1  \
# 9   ENSG00000003402_6      77.272728       7.575758  ENSG00000003402_9
# 10  ENSG00000003436_4      22.082711      10.555142  ENSG00000003436_2
# 14                NaN      75.714287            NaN  ENSG00000004487_1
# 32                NaN      19.819595            NaN  ENSG00000006282_1
# 60                NaN      39.024387            NaN  ENSG00000010278_3
#
#             neg_iso_2  neg_iso_1_dpi  neg_iso_2_dpi     adj_p_val    gname
# 9   ENSG00000003402_7     -31.717173     -22.222223  5.296535e-13    CFLAR
# 10  ENSG00000003436_5     -30.435921      -1.818182  7.003007e-06     TFPI
# 14                NaN     -75.714285            NaN  1.141621e-02    KDM1A
# 32                NaN     -19.819595            NaN  4.915014e-02  SPATA20
# 60  ENSG00000010278_1     -38.605976      -0.418410  3.486194e-20      CD9

# %% [markdown]
# Finally, for transcriptomes generated with [Cerberus](https://github.com/mortazavilab/cerberus), Swan automatically tracks intron chain usage, and you can perform intron chain switching analysis with `kind='ic'` as input to the `die_gene_test()` function.

# %%
sg_brain = swan.read('swan_modelad.p')

# find genes that exhibit DIE for ICs between genotypes
die_table, die_results = sg_brain.die_gene_test(kind='ic',
                                                obs_col='genotype',
                                                obs_conditions=['b6n', '5xfad'])
die_table.head()
# Out:
# Read in graph from swan_modelad.p
#                  gid         p_val        dpi            pos_iso_1  \
# 0  ENCODEMG000055991  4.100695e-01   6.071428  ENCODEMG000055991_2
# 1  ENCODEMG000055998  6.190162e-01   9.722223  ENCODEMG000055998_2
# 2  ENCODEMG000056718  8.081718e-07   6.289159                  NaN
# 3  ENCODEMG000056804  2.107047e-03  27.863049  ENCODEMG000056804_1
# 4  ENCODEMG000063411  7.699701e-01  12.500000  ENCODEMG000063411_1
#
#              pos_iso_2  pos_iso_1_dpi  pos_iso_2_dpi            neg_iso_1  \
# 0  ENCODEMG000055991_3       3.571428       2.500000  ENCODEMG000055991_1
# 1                  NaN       9.722223            NaN  ENCODEMG000055998_1
# 2                  NaN       2.329770       1.953835                  NaN
# 3                  NaN      27.863047            NaN  ENCODEMG000056804_2
# 4                  NaN      12.500000            NaN  ENCODEMG000063411_2
#
#   neg_iso_2  neg_iso_1_dpi  neg_iso_2_dpi  adj_p_val              gname
# 0       NaN      -6.071426            NaN   0.707992  ENCODEMG000055991
# 1       NaN      -9.722218            NaN   0.836200  ENCODEMG000055998
# 2       NaN      -3.339438      -2.949721   0.000020  ENCODEMG000056718
# 3       NaN     -27.863049            NaN   0.021510  ENCODEMG000056804
# 4       NaN     -12.500000            NaN   0.919808  ENCODEMG000063411

# %% [markdown]
# ## <a name="multi_gb"></a>Combining metadata columns

# %% [markdown]
# What if none of the metadata columns you have summarize the comparisons you want to make? What if I want to find differentially expressed genes or transcripts, or find isoform-switching genes between hffc6 replicate 3 and hepg2 replicate 1?

# %%
sg.adata.obs.head()
# Out:
#         cell_line replicate  dataset  total_counts
# dataset
# hepg2_1     hepg2         1  hepg2_1      499647.0
# hepg2_2     hepg2         2  hepg2_2      848447.0
# hffc6_1     hffc6         1  hffc6_1      761493.0
# hffc6_2     hffc6         2  hffc6_2      787967.0
# hffc6_3     hffc6         3  hffc6_3      614921.0

# %% [markdown]
# Let's ignore for a moment the fact that the `dataset` column does effectively capture both replicate as well as cell line metadata. This may not always be the case with more complex datasets. Swan has a function to concatenate columns together and add them as an additional column to the metadata tables. Use the following code to generate a new column that concatenates as many preexisting metadata columns as you wish:

# %%
col_name = sg.add_multi_groupby(['cell_line', 'replicate'])

print(col_name)
print(sg.adata.obs.head())
# Out:
# cell_line_replicate
#         cell_line replicate  dataset  total_counts cell_line_replicate
# dataset
# hepg2_1     hepg2         1  hepg2_1      499647.0             hepg2_1
# hepg2_2     hepg2         2  hepg2_2      848447.0             hepg2_2
# hffc6_1     hffc6         1  hffc6_1      761493.0             hffc6_1
# hffc6_2     hffc6         2  hffc6_2      787967.0             hffc6_2
# hffc6_3     hffc6         3  hffc6_3      614921.0             hffc6_3

# %% [markdown]
# The added column in `col_name` can then be used as the `obs_col` input to `die_gene_test()` as follows:

# %%
obs_col = col_name
obs_conditions = ['hffc6_3', 'hepg2_1']


die_table, die_results = sg.die_gene_test(kind='iso',
                                          obs_col=obs_col, 
                                          obs_conditions=obs_conditions)
# Out:
# /Users/fairliereese/miniconda3/lib/python3.7/site-packages/anndata/_core/anndata.py:794: UserWarning:
# AnnData expects .obs.index to contain strings, but got values like:
#     [0, 1]
#
#     Inferred to be: integer
#
#   value_idx = self._prep_dim_index(value.index, attr)
# training location model: False
# training scale model: True
# iter   0: ll=4391080.510328
# iter   1: ll=4391080.510328, converged: 0.00% (loc: 100.00%, scale update: False), in 0.00sec
# iter   2: ll=2990612.252568, converged: 82.30% (loc: 82.30%, scale update: True), in 80.66sec
# iter   3: ll=2990612.252568, converged: 82.30% (loc: 100.00%, scale update: False), in 0.00sec
# iter   4: ll=2736937.375560, converged: 91.10% (loc: 91.10%, scale update: True), in 17.41sec
# iter   5: ll=2736937.375560, converged: 91.10% (loc: 100.00%, scale update: False), in 0.00sec
# iter   6: ll=2735022.903744, converged: 98.06% (loc: 98.06%, scale update: True), in 10.08sec
# iter   7: ll=2735022.903744, converged: 98.06% (loc: 100.00%, scale update: False), in 0.00sec
# iter   8: ll=2734765.741299, converged: 99.81% (loc: 99.81%, scale update: True), in 4.18sec
# iter   9: ll=2734765.741299, converged: 99.81% (loc: 100.00%, scale update: False), in 0.00sec
# iter  10: ll=2734727.647088, converged: 99.98% (loc: 99.98%, scale update: True), in 1.82sec
# iter  11: ll=2734727.647088, converged: 99.98% (loc: 100.00%, scale update: False), in 0.00sec
# iter  12: ll=2734720.701429, converged: 100.00% (loc: 100.00%, scale update: True), in 1.67sec
# iter  13: ll=2734720.701429, converged: 100.00% (loc: 100.00%, scale update: False), in 0.00sec
# iter  14: ll=2734720.701429, converged: 100.00% (loc: 100.00%, scale update: True), in 0.65sec
# /Users/fairliereese/miniconda3/lib/python3.7/site-packages/dask/array/core.py:2622: RuntimeWarning: divide by zero encountered in true_divide
#   size = (limit / dtype.itemsize / largest_block) ** (1 / len(autos))
# training location model: True
# training scale model: True
# iter   0: ll=9704955.674048
# caught 13674 linalg singular matrix errors
# iter   1: ll=9704955.674048, converged: 0.00% (loc: 100.00%, scale update: False), in 14.53sec
# iter   2: ll=5938670.795058, converged: 89.26% (loc: 89.26%, scale update: True), in 285.23sec
# caught 13674 linalg singular matrix errors
# iter   3: ll=5938670.794538, converged: 89.26% (loc: 100.00%, scale update: False), in 13.05sec
# iter   4: ll=5938670.794538, converged: 89.26% (loc: 100.00%, scale update: False), in 2.11sec
# iter   5: ll=4749172.560584, converged: 96.79% (loc: 96.79%, scale update: True), in 35.51sec
# caught 825 linalg singular matrix errors
# iter   6: ll=4749172.547157, converged: 96.79% (loc: 100.00%, scale update: False), in 11.85sec
# iter   7: ll=4749172.547157, converged: 96.79% (loc: 100.00%, scale update: False), in 2.14sec
# iter   8: ll=4746120.485244, converged: 98.84% (loc: 98.84%, scale update: True), in 16.83sec
# caught 48 linalg singular matrix errors
# iter   9: ll=4746120.485244, converged: 98.84% (loc: 100.00%, scale update: False), in 9.08sec
# iter  10: ll=4745269.832568, converged: 99.36% (loc: 99.36%, scale update: True), in 10.10sec
# caught 6 linalg singular matrix errors
# iter  11: ll=4745269.832568, converged: 99.36% (loc: 100.00%, scale update: False), in 7.07sec
# iter  12: ll=4743622.656286, converged: 99.67% (loc: 99.67%, scale update: True), in 8.59sec
# iter  13: ll=4743622.656286, converged: 99.67% (loc: 100.00%, scale update: False), in 5.22sec
# iter  14: ll=4743319.573837, converged: 99.82% (loc: 99.82%, scale update: True), in 8.93sec
# iter  15: ll=4743319.573837, converged: 99.82% (loc: 100.00%, scale update: False), in 4.02sec
# iter  16: ll=4743319.573837, converged: 100.00% (loc: 100.00%, scale update: True), in 6.73sec
# /Users/fairliereese/miniconda3/lib/python3.7/site-packages/dask/array/core.py:2622: RuntimeWarning: divide by zero encountered in true_divide
#   size = (limit / dtype.itemsize / largest_block) ** (1 / len(autos))

# %% [markdown]
# ## <a name="es_ir"></a>Exon skipping and intron retention

# %% [markdown]
# Swan can detect novel (unannotated) exon skipping and intron retention events.

# %% [markdown]
# To obtain a dataframe of novel exon skipping events, run the following code:

# %%
# returns a DataFrame of genes, transcripts, and specific edges in 
# the SwanGraph with novel exon skipping events
es_df = sg.find_es_genes(verbose=True)
# Out:
# Testing each novel edge for exon skipping:   0%|          | 0/855 [00:00<?, ?it/s]
# Analyzing 855 intronic edges for ES
# Testing each novel edge for exon skipping: 100%|██████████| 855/855 [1:26:06<00:00,  6.13s/it]
# Found 529 novel es events in 149 transcripts.

# %%
es_df.head()
# Out:
#                   gid              tid  edge_id
# 0  ENSG00000157916.19  TALONT000218256   952616
# 0  ENSG00000122406.13  TALONT000425229   952716
# 0   ENSG00000224093.5  TALONT000434035   952720
# 0   ENSG00000224093.5  TALONT000434035   952720
# 0   ENSG00000224093.5  TALONT000434035   952720

# %% [markdown]
# To obtain a list of genes containing novel intron retention events, run the following code:

# %%
# returns a DataFrame of genes, transcripts, and specific edges in 
# the SwanGraph with novel intron retaining events
ir_df = sg.find_ir_genes(verbose=True)
# Out:
#   0%|          | 0/1186 [00:00<?, ?it/s]
# Testing each novel edge for intron retention:   0%|          | 0/1186 [00:00<?, ?it/s]
# Analyzing 1186 exonic edges for IR
# Testing each novel edge for exon skipping: 100%|██████████| 855/855 [1:26:11<00:00,  6.05s/it]
#
# Testing each novel edge for intron retention:   0%|          | 1/1186 [00:05<1:54:40,  5.81s/it]
# Testing each novel edge for intron retention:   0%|          | 2/1186 [00:12<2:01:22,  6.15s/it]
# Testing each novel edge for intron retention:   0%|          | 3/1186 [00:17<1:57:27,  5.96s/it]
# Testing each novel edge for intron retention:   0%|          | 4/1186 [00:24<2:00:54,  6.14s/it]
# Testing each novel edge for intron retention:   0%|          | 5/1186 [00:30<1:58:07,  6.00s/it]
# Testing each novel edge for intron retention:   1%|          | 6/1186 [00:35<1:56:44,  5.94s/it]
# Testing each novel edge for intron retention:   1%|          | 7/1186 [00:42<1:59:37,  6.09s/it]
# Testing each novel edge for intron retention:   1%|          | 8/1186 [00:48<1:57:20,  5.98s/it]
# Testing each novel edge for intron retention:   1%|          | 9/1186 [00:54<1:59:13,  6.08s/it]
# Testing each novel edge for intron retention:   1%|          | 10/1186 [01:00<1:57:20,  5.99s/it]
# Testing each novel edge for intron retention:   1%|          | 11/1186 [01:05<1:56:12,  5.93s/it]
# Testing each novel edge for intron retention:   1%|          | 12/1186 [01:11<1:55:07,  5.88s/it]
# Testing each novel edge for intron retention:   1%|          | 13/1186 [01:17<1:57:22,  6.00s/it]
# Testing each novel edge for intron retention:   1%|          | 14/1186 [01:23<1:55:49,  5.93s/it]
# Testing each novel edge for intron retention:   1%|▏         | 15/1186 [01:30<1:58:15,  6.06s/it]
# Testing each novel edge for intron retention:   1%|▏         | 16/1186 [01:35<1:56:33,  5.98s/it]
# Testing each novel edge for intron retention:   1%|▏         | 17/1186 [01:42<1:59:01,  6.11s/it]
# Testing each novel edge for intron retention:   2%|▏         | 18/1186 [01:48<1:56:52,  6.00s/it]
# Testing each novel edge for intron retention:   2%|▏         | 19/1186 [01:54<1:58:40,  6.10s/it]
# Testing each novel edge for intron retention:   2%|▏         | 20/1186 [02:00<1:56:29,  5.99s/it]
# Testing each novel edge for intron retention:   2%|▏         | 21/1186 [02:05<1:55:18,  5.94s/it]
# Testing each novel edge for intron retention:   2%|▏         | 22/1186 [02:12<1:57:41,  6.07s/it]
# Testing each novel edge for intron retention:   2%|▏         | 23/1186 [02:18<1:55:46,  5.97s/it]
# Testing each novel edge for intron retention:   2%|▏         | 24/1186 [02:24<1:57:52,  6.09s/it]
# Testing each novel edge for intron retention:   2%|▏         | 25/1186 [02:30<1:55:51,  5.99s/it]
# Testing each novel edge for intron retention:   2%|▏         | 26/1186 [02:36<1:58:10,  6.11s/it]
# Testing each novel edge for intron retention:   2%|▏         | 27/1186 [02:42<1:56:54,  6.05s/it]
# Testing each novel edge for intron retention:   2%|▏         | 28/1186 [02:48<1:58:41,  6.15s/it]
# Testing each novel edge for intron retention:   2%|▏         | 29/1186 [02:54<1:56:25,  6.04s/it]
# Testing each novel edge for intron retention:   3%|▎         | 30/1186 [03:00<1:54:38,  5.95s/it]
# Testing each novel edge for intron retention:   3%|▎         | 31/1186 [03:06<1:57:06,  6.08s/it]
# Testing each novel edge for intron retention:   3%|▎         | 32/1186 [03:12<1:55:10,  5.99s/it]
# Testing each novel edge for intron retention:   3%|▎         | 33/1186 [03:18<1:53:53,  5.93s/it]
# Testing each novel edge for intron retention:   3%|▎         | 34/1186 [03:24<1:56:21,  6.06s/it]
# Testing each novel edge for intron retention:   3%|▎         | 35/1186 [03:30<1:54:38,  5.98s/it]
# Testing each novel edge for intron retention:   3%|▎         | 36/1186 [03:36<1:53:37,  5.93s/it]
# Testing each novel edge for intron retention:   3%|▎         | 37/1186 [03:42<1:52:30,  5.87s/it]
# Testing each novel edge for intron retention:   3%|▎         | 38/1186 [03:48<1:55:43,  6.05s/it]
# Testing each novel edge for intron retention:   3%|▎         | 39/1186 [03:54<1:53:52,  5.96s/it]
# Testing each novel edge for intron retention:   3%|▎         | 40/1186 [04:00<1:56:30,  6.10s/it]
# Testing each novel edge for intron retention:   3%|▎         | 41/1186 [04:06<1:54:20,  5.99s/it]
# Testing each novel edge for intron retention:   4%|▎         | 42/1186 [04:12<1:56:07,  6.09s/it]
# Testing each novel edge for intron retention:   4%|▎         | 43/1186 [04:18<1:54:30,  6.01s/it]
# Testing each novel edge for intron retention:   4%|▎         | 44/1186 [04:24<1:52:54,  5.93s/it]
# Testing each novel edge for intron retention:   4%|▍         | 45/1186 [04:30<1:56:17,  6.11s/it]
# Testing each novel edge for intron retention:   4%|▍         | 46/1186 [04:36<1:54:17,  6.02s/it]
# Testing each novel edge for intron retention:   4%|▍         | 47/1186 [04:42<1:52:48,  5.94s/it]
# Testing each novel edge for intron retention:   4%|▍         | 48/1186 [04:48<1:54:58,  6.06s/it]
# Testing each novel edge for intron retention:   4%|▍         | 49/1186 [04:54<1:52:54,  5.96s/it]
# Testing each novel edge for intron retention:   4%|▍         | 50/1186 [05:00<1:55:56,  6.12s/it]
# Testing each novel edge for intron retention:   4%|▍         | 51/1186 [05:06<1:53:41,  6.01s/it]
# Testing each novel edge for intron retention:   4%|▍         | 52/1186 [05:12<1:51:57,  5.92s/it]
# Testing each novel edge for intron retention:   4%|▍         | 53/1186 [05:18<1:54:57,  6.09s/it]
# Testing each novel edge for intron retention:   5%|▍         | 54/1186 [05:24<1:53:11,  6.00s/it]
# Testing each novel edge for intron retention:   5%|▍         | 55/1186 [05:31<1:55:14,  6.11s/it]
# Testing each novel edge for intron retention:   5%|▍         | 56/1186 [05:36<1:53:23,  6.02s/it]
# Testing each novel edge for intron retention:   5%|▍         | 57/1186 [05:43<1:55:11,  6.12s/it]
# Testing each novel edge for intron retention:   5%|▍         | 58/1186 [05:49<1:53:16,  6.03s/it]
# Testing each novel edge for intron retention:   5%|▍         | 59/1186 [05:55<1:54:59,  6.12s/it]
# Testing each novel edge for intron retention:   5%|▌         | 60/1186 [06:01<1:52:32,  6.00s/it]
# Testing each novel edge for intron retention:   5%|▌         | 61/1186 [06:06<1:51:19,  5.94s/it]
# Testing each novel edge for intron retention:   5%|▌         | 62/1186 [06:13<1:53:32,  6.06s/it]
# Testing each novel edge for intron retention:   5%|▌         | 63/1186 [06:19<1:52:00,  5.98s/it]
# Testing each novel edge for intron retention:   5%|▌         | 64/1186 [06:24<1:50:35,  5.91s/it]
# Testing each novel edge for intron retention:   5%|▌         | 65/1186 [06:31<1:52:37,  6.03s/it]
# Testing each novel edge for intron retention:   6%|▌         | 66/1186 [06:36<1:51:01,  5.95s/it]
# Testing each novel edge for intron retention:   6%|▌         | 67/1186 [06:43<1:52:50,  6.05s/it]
# Testing each novel edge for intron retention:   6%|▌         | 68/1186 [06:48<1:51:23,  5.98s/it]
# Testing each novel edge for intron retention:   6%|▌         | 69/1186 [06:55<1:52:58,  6.07s/it]
# Testing each novel edge for intron retention:   6%|▌         | 70/1186 [07:00<1:51:04,  5.97s/it]
# Testing each novel edge for intron retention:   6%|▌         | 71/1186 [07:07<1:53:12,  6.09s/it]
# Testing each novel edge for intron retention:   6%|▌         | 72/1186 [07:13<1:51:15,  5.99s/it]
# Testing each novel edge for intron retention:   6%|▌         | 73/1186 [07:19<1:53:16,  6.11s/it]
# Testing each novel edge for intron retention:   6%|▌         | 74/1186 [07:25<1:51:15,  6.00s/it]
# Testing each novel edge for intron retention:   6%|▋         | 75/1186 [07:31<1:50:05,  5.95s/it]
# Testing each novel edge for intron retention:   6%|▋         | 76/1186 [07:36<1:48:44,  5.88s/it]
# Testing each novel edge for intron retention:   6%|▋         | 77/1186 [07:43<1:51:36,  6.04s/it]
# Testing each novel edge for intron retention:   7%|▋         | 78/1186 [07:48<1:49:40,  5.94s/it]
# Testing each novel edge for intron retention:   7%|▋         | 79/1186 [07:55<1:51:47,  6.06s/it]
# Testing each novel edge for intron retention:   7%|▋         | 80/1186 [08:00<1:49:55,  5.96s/it]
# Testing each novel edge for intron retention:   7%|▋         | 81/1186 [08:07<1:52:30,  6.11s/it]
# Testing each novel edge for intron retention:   7%|▋         | 82/1186 [08:13<1:50:22,  6.00s/it]
# Testing each novel edge for intron retention:   7%|▋         | 83/1186 [08:19<1:52:01,  6.09s/it]
# Testing each novel edge for intron retention:   7%|▋         | 84/1186 [08:25<1:50:06,  5.99s/it]
# Testing each novel edge for intron retention:   7%|▋         | 85/1186 [08:30<1:48:27,  5.91s/it]
# Testing each novel edge for intron retention:   7%|▋         | 86/1186 [08:37<1:51:06,  6.06s/it]
# Testing each novel edge for intron retention:   7%|▋         | 87/1186 [08:43<1:49:17,  5.97s/it]
# Testing each novel edge for intron retention:   7%|▋         | 88/1186 [08:49<1:51:20,  6.08s/it]
# Testing each novel edge for intron retention:   8%|▊         | 89/1186 [08:55<1:49:48,  6.01s/it]
# Testing each novel edge for intron retention:   8%|▊         | 90/1186 [09:01<1:51:18,  6.09s/it]
# Testing each novel edge for intron retention:   8%|▊         | 91/1186 [09:07<1:49:40,  6.01s/it]
# Testing each novel edge for intron retention:   8%|▊         | 92/1186 [09:13<1:48:12,  5.93s/it]
# Testing each novel edge for intron retention:   8%|▊         | 93/1186 [09:19<1:50:33,  6.07s/it]
# Testing each novel edge for intron retention:   8%|▊         | 94/1186 [09:25<1:48:51,  5.98s/it]
# Testing each novel edge for intron retention:   8%|▊         | 95/1186 [09:31<1:47:48,  5.93s/it]
# Testing each novel edge for intron retention:   8%|▊         | 96/1186 [09:36<1:47:02,  5.89s/it]
# Testing each novel edge for intron retention:   8%|▊         | 97/1186 [09:43<1:49:35,  6.04s/it]
# Testing each novel edge for intron retention:   8%|▊         | 98/1186 [09:49<1:48:32,  5.99s/it]
# Testing each novel edge for intron retention:   8%|▊         | 99/1186 [09:55<1:50:18,  6.09s/it]
# Testing each novel edge for intron retention:   8%|▊         | 100/1186 [10:01<1:48:20,  5.99s/it]
# Testing each novel edge for intron retention:   9%|▊         | 101/1186 [10:07<1:50:29,  6.11s/it]
# Testing each novel edge for intron retention:   9%|▊         | 102/1186 [10:13<1:48:25,  6.00s/it]
# Testing each novel edge for intron retention:   9%|▊         | 103/1186 [10:19<1:50:54,  6.14s/it]
# Testing each novel edge for intron retention:   9%|▉         | 104/1186 [10:25<1:49:00,  6.04s/it]
# Testing each novel edge for intron retention:   9%|▉         | 105/1186 [10:31<1:47:35,  5.97s/it]
# Testing each novel edge for intron retention:   9%|▉         | 106/1186 [10:37<1:49:56,  6.11s/it]
# Testing each novel edge for intron retention:   9%|▉         | 107/1186 [10:43<1:48:01,  6.01s/it]
# Testing each novel edge for intron retention:   9%|▉         | 108/1186 [10:49<1:46:44,  5.94s/it]
# Testing each novel edge for intron retention:   9%|▉         | 109/1186 [10:55<1:48:58,  6.07s/it]
# Testing each novel edge for intron retention:   9%|▉         | 110/1186 [11:01<1:47:22,  5.99s/it]
# Testing each novel edge for intron retention:   9%|▉         | 111/1186 [11:07<1:46:17,  5.93s/it]
# Testing each novel edge for intron retention:   9%|▉         | 112/1186 [11:13<1:45:22,  5.89s/it]
# Testing each novel edge for intron retention:  10%|▉         | 113/1186 [11:19<1:47:46,  6.03s/it]
# Testing each novel edge for intron retention:  10%|▉         | 114/1186 [11:25<1:46:36,  5.97s/it]
# Testing each novel edge for intron retention:  10%|▉         | 115/1186 [11:31<1:48:21,  6.07s/it]
# Testing each novel edge for intron retention:  10%|▉         | 116/1186 [11:37<1:46:49,  5.99s/it]
# Testing each novel edge for intron retention:  10%|▉         | 117/1186 [11:44<1:49:26,  6.14s/it]
# Testing each novel edge for intron retention:  10%|▉         | 118/1186 [11:49<1:47:33,  6.04s/it]
# Testing each novel edge for intron retention:  10%|█         | 119/1186 [11:55<1:45:53,  5.95s/it]
# Testing each novel edge for intron retention:  10%|█         | 120/1186 [12:01<1:48:06,  6.09s/it]
# Testing each novel edge for intron retention:  10%|█         | 121/1186 [12:07<1:46:28,  6.00s/it]
# Testing each novel edge for intron retention:  10%|█         | 122/1186 [12:14<1:48:19,  6.11s/it]
# Testing each novel edge for intron retention:  10%|█         | 123/1186 [12:19<1:46:21,  6.00s/it]
# Testing each novel edge for intron retention:  10%|█         | 124/1186 [12:25<1:44:59,  5.93s/it]
# Testing each novel edge for intron retention:  11%|█         | 125/1186 [12:32<1:47:19,  6.07s/it]
# Testing each novel edge for intron retention:  11%|█         | 126/1186 [12:38<1:46:30,  6.03s/it]
# Testing each novel edge for intron retention:  11%|█         | 127/1186 [12:43<1:45:14,  5.96s/it]
# Testing each novel edge for intron retention:  11%|█         | 128/1186 [12:50<1:47:41,  6.11s/it]
# Testing each novel edge for intron retention:  11%|█         | 129/1186 [12:56<1:45:46,  6.00s/it]
# Testing each novel edge for intron retention:  11%|█         | 130/1186 [13:01<1:44:15,  5.92s/it]
# Testing each novel edge for intron retention:  11%|█         | 131/1186 [13:08<1:46:37,  6.06s/it]
# Testing each novel edge for intron retention:  11%|█         | 132/1186 [13:14<1:45:49,  6.02s/it]
# Testing each novel edge for intron retention:  11%|█         | 133/1186 [13:19<1:44:34,  5.96s/it]
# Testing each novel edge for intron retention:  11%|█▏        | 134/1186 [13:26<1:46:35,  6.08s/it]
# Testing each novel edge for intron retention:  11%|█▏        | 135/1186 [13:32<1:44:53,  5.99s/it]
# Testing each novel edge for intron retention:  11%|█▏        | 136/1186 [13:38<1:47:17,  6.13s/it]
# Testing each novel edge for intron retention:  12%|█▏        | 137/1186 [13:44<1:45:22,  6.03s/it]
# Testing each novel edge for intron retention:  12%|█▏        | 138/1186 [13:50<1:43:49,  5.94s/it]
# Testing each novel edge for intron retention:  12%|█▏        | 139/1186 [13:55<1:42:41,  5.88s/it]
# Testing each novel edge for intron retention:  12%|█▏        | 140/1186 [14:02<1:44:43,  6.01s/it]
# Testing each novel edge for intron retention:  12%|█▏        | 141/1186 [14:07<1:43:10,  5.92s/it]
# Testing each novel edge for intron retention:  12%|█▏        | 142/1186 [14:14<1:45:38,  6.07s/it]
# Testing each novel edge for intron retention:  12%|█▏        | 143/1186 [14:19<1:43:57,  5.98s/it]
# Testing each novel edge for intron retention:  12%|█▏        | 144/1186 [14:26<1:45:56,  6.10s/it]
# Testing each novel edge for intron retention:  12%|█▏        | 145/1186 [14:32<1:44:11,  6.01s/it]
# Testing each novel edge for intron retention:  12%|█▏        | 146/1186 [14:38<1:46:10,  6.13s/it]
# Testing each novel edge for intron retention:  12%|█▏        | 147/1186 [14:44<1:44:27,  6.03s/it]
# Testing each novel edge for intron retention:  12%|█▏        | 148/1186 [14:50<1:42:49,  5.94s/it]
# Testing each novel edge for intron retention:  13%|█▎        | 149/1186 [14:56<1:44:50,  6.07s/it]
# Testing each novel edge for intron retention:  13%|█▎        | 150/1186 [15:02<1:43:45,  6.01s/it]
# Testing each novel edge for intron retention:  13%|█▎        | 151/1186 [15:08<1:43:00,  5.97s/it]
# Testing each novel edge for intron retention:  13%|█▎        | 152/1186 [15:13<1:41:52,  5.91s/it]
# Testing each novel edge for intron retention:  13%|█▎        | 153/1186 [15:20<1:43:57,  6.04s/it]
# Testing each novel edge for intron retention:  13%|█▎        | 154/1186 [15:26<1:42:36,  5.97s/it]
# Testing each novel edge for intron retention:  13%|█▎        | 155/1186 [15:32<1:44:45,  6.10s/it]
# Testing each novel edge for intron retention:  13%|█▎        | 156/1186 [15:38<1:44:20,  6.08s/it]
# Testing each novel edge for intron retention:  13%|█▎        | 157/1186 [15:44<1:45:54,  6.18s/it]
# Testing each novel edge for intron retention:  13%|█▎        | 158/1186 [15:50<1:43:46,  6.06s/it]
# Testing each novel edge for intron retention:  13%|█▎        | 159/1186 [15:56<1:42:14,  5.97s/it]
# Testing each novel edge for intron retention:  13%|█▎        | 160/1186 [16:02<1:44:00,  6.08s/it]
# Testing each novel edge for intron retention:  14%|█▎        | 161/1186 [16:08<1:42:26,  6.00s/it]
# Testing each novel edge for intron retention:  14%|█▎        | 162/1186 [16:14<1:41:08,  5.93s/it]
# Testing each novel edge for intron retention:  14%|█▎        | 163/1186 [16:20<1:43:23,  6.06s/it]
# Testing each novel edge for intron retention:  14%|█▍        | 164/1186 [16:26<1:41:46,  5.97s/it]
# Testing each novel edge for intron retention:  14%|█▍        | 165/1186 [16:32<1:43:44,  6.10s/it]
# Testing each novel edge for intron retention:  14%|█▍        | 166/1186 [16:38<1:42:31,  6.03s/it]
# Testing each novel edge for intron retention:  14%|█▍        | 167/1186 [16:44<1:41:11,  5.96s/it]
# Testing each novel edge for intron retention:  14%|█▍        | 168/1186 [16:50<1:43:15,  6.09s/it]
# Testing each novel edge for intron retention:  14%|█▍        | 169/1186 [16:56<1:41:21,  5.98s/it]
# Testing each novel edge for intron retention:  14%|█▍        | 170/1186 [17:03<1:43:16,  6.10s/it]
# Testing each novel edge for intron retention:  14%|█▍        | 171/1186 [17:08<1:41:41,  6.01s/it]
# Testing each novel edge for intron retention:  15%|█▍        | 172/1186 [17:15<1:43:23,  6.12s/it]
# Testing each novel edge for intron retention:  15%|█▍        | 173/1186 [17:21<1:41:25,  6.01s/it]
# Testing each novel edge for intron retention:  15%|█▍        | 174/1186 [17:27<1:42:55,  6.10s/it]
# Testing each novel edge for intron retention:  15%|█▍        | 175/1186 [17:33<1:42:04,  6.06s/it]
# Testing each novel edge for intron retention:  15%|█▍        | 176/1186 [17:40<1:45:36,  6.27s/it]
# Testing each novel edge for intron retention:  15%|█▍        | 177/1186 [17:46<1:47:29,  6.39s/it]
# Testing each novel edge for intron retention:  15%|█▌        | 178/1186 [17:52<1:44:35,  6.23s/it]
# Testing each novel edge for intron retention:  15%|█▌        | 179/1186 [17:58<1:43:03,  6.14s/it]
# Testing each novel edge for intron retention:  15%|█▌        | 180/1186 [18:04<1:43:51,  6.19s/it]
# Testing each novel edge for intron retention:  15%|█▌        | 181/1186 [18:10<1:42:11,  6.10s/it]
# Testing each novel edge for intron retention:  15%|█▌        | 182/1186 [18:17<1:43:28,  6.18s/it]
# Testing each novel edge for intron retention:  15%|█▌        | 183/1186 [18:22<1:41:16,  6.06s/it]
# Testing each novel edge for intron retention:  16%|█▌        | 184/1186 [18:29<1:42:28,  6.14s/it]
# Testing each novel edge for intron retention:  16%|█▌        | 185/1186 [18:34<1:40:38,  6.03s/it]
# Testing each novel edge for intron retention:  16%|█▌        | 186/1186 [18:41<1:42:33,  6.15s/it]
# Testing each novel edge for intron retention:  16%|█▌        | 187/1186 [18:47<1:40:42,  6.05s/it]
# Testing each novel edge for intron retention:  16%|█▌        | 188/1186 [18:53<1:42:16,  6.15s/it]
# Testing each novel edge for intron retention:  16%|█▌        | 189/1186 [18:59<1:40:38,  6.06s/it]
# Testing each novel edge for intron retention:  16%|█▌        | 190/1186 [19:05<1:39:38,  6.00s/it]
# Testing each novel edge for intron retention:  16%|█▌        | 191/1186 [19:11<1:38:45,  5.96s/it]
# Testing each novel edge for intron retention:  16%|█▌        | 192/1186 [19:17<1:40:44,  6.08s/it]
# Testing each novel edge for intron retention:  16%|█▋        | 193/1186 [19:23<1:39:21,  6.00s/it]
# Testing each novel edge for intron retention:  16%|█▋        | 194/1186 [19:29<1:41:08,  6.12s/it]
# Testing each novel edge for intron retention:  16%|█▋        | 195/1186 [19:35<1:39:34,  6.03s/it]
# Testing each novel edge for intron retention:  17%|█▋        | 196/1186 [19:42<1:41:31,  6.15s/it]
# Testing each novel edge for intron retention:  17%|█▋        | 197/1186 [19:47<1:39:41,  6.05s/it]
# Testing each novel edge for intron retention:  17%|█▋        | 198/1186 [19:54<1:41:00,  6.13s/it]
# Testing each novel edge for intron retention:  17%|█▋        | 199/1186 [19:59<1:39:02,  6.02s/it]
# Testing each novel edge for intron retention:  17%|█▋        | 200/1186 [20:05<1:38:00,  5.96s/it]
# Testing each novel edge for intron retention:  17%|█▋        | 201/1186 [20:12<1:39:56,  6.09s/it]
# Testing each novel edge for intron retention:  17%|█▋        | 202/1186 [20:17<1:38:10,  5.99s/it]
# Testing each novel edge for intron retention:  17%|█▋        | 203/1186 [20:24<1:39:57,  6.10s/it]
# Testing each novel edge for intron retention:  17%|█▋        | 204/1186 [20:29<1:38:14,  6.00s/it]
# Testing each novel edge for intron retention:  17%|█▋        | 205/1186 [20:36<1:40:01,  6.12s/it]
# Testing each novel edge for intron retention:  17%|█▋        | 206/1186 [20:42<1:38:41,  6.04s/it]
# Testing each novel edge for intron retention:  17%|█▋        | 207/1186 [20:48<1:37:15,  5.96s/it]
# Testing each novel edge for intron retention:  18%|█▊        | 208/1186 [20:54<1:39:03,  6.08s/it]
# Testing each novel edge for intron retention:  18%|█▊        | 209/1186 [21:00<1:37:33,  5.99s/it]
# Testing each novel edge for intron retention:  18%|█▊        | 210/1186 [21:05<1:36:21,  5.92s/it]
# Testing each novel edge for intron retention:  18%|█▊        | 211/1186 [21:11<1:35:54,  5.90s/it]
# Testing each novel edge for intron retention:  18%|█▊        | 212/1186 [21:18<1:37:58,  6.04s/it]
# Testing each novel edge for intron retention:  18%|█▊        | 213/1186 [21:23<1:36:27,  5.95s/it]
# Testing each novel edge for intron retention:  18%|█▊        | 214/1186 [21:30<1:38:10,  6.06s/it]
# Testing each novel edge for intron retention:  18%|█▊        | 215/1186 [21:35<1:36:39,  5.97s/it]
# Testing each novel edge for intron retention:  18%|█▊        | 216/1186 [21:42<1:38:34,  6.10s/it]
# Testing each novel edge for intron retention:  18%|█▊        | 217/1186 [21:48<1:37:01,  6.01s/it]
# Testing each novel edge for intron retention:  18%|█▊        | 218/1186 [21:54<1:38:46,  6.12s/it]
# Testing each novel edge for intron retention:  18%|█▊        | 219/1186 [22:00<1:37:14,  6.03s/it]
# Testing each novel edge for intron retention:  19%|█▊        | 220/1186 [22:06<1:36:09,  5.97s/it]
# Testing each novel edge for intron retention:  19%|█▊        | 221/1186 [22:12<1:37:55,  6.09s/it]
# Testing each novel edge for intron retention:  19%|█▊        | 222/1186 [22:18<1:36:25,  6.00s/it]
# Testing each novel edge for intron retention:  34%|███▍      | 407/1186 [40:54<1:18:50,  6.07s/it]
# Testing each novel edge for intron retention:  34%|███▍      | 408/1186 [41:00<1:17:30,  5.98s/it]
# Testing each novel edge for intron retention:  34%|███▍      | 409/1186 [41:05<1:16:24,  5.90s/it]
# Testing each novel edge for intron retention:  35%|███▍      | 410/1186 [41:12<1:18:29,  6.07s/it]
# Testing each novel edge for intron retention:  35%|███▍      | 411/1186 [41:17<1:17:14,  5.98s/it]
# Testing each novel edge for intron retention:  35%|███▍      | 412/1186 [41:24<1:18:51,  6.11s/it]
# Testing each novel edge for intron retention:  35%|███▍      | 413/1186 [41:30<1:17:19,  6.00s/it]
# Testing each novel edge for intron retention:  35%|███▍      | 414/1186 [41:36<1:18:35,  6.11s/it]
# Testing each novel edge for intron retention:  35%|███▍      | 415/1186 [41:42<1:17:24,  6.02s/it]
# Testing each novel edge for intron retention:  35%|███▌      | 416/1186 [41:48<1:18:33,  6.12s/it]
# Testing each novel edge for intron retention:  35%|███▌      | 417/1186 [41:54<1:17:00,  6.01s/it]
# Testing each novel edge for intron retention:  35%|███▌      | 418/1186 [42:00<1:18:20,  6.12s/it]
# Testing each novel edge for intron retention:  35%|███▌      | 419/1186 [42:06<1:16:53,  6.01s/it]
# Testing each novel edge for intron retention:  35%|███▌      | 420/1186 [42:12<1:15:47,  5.94s/it]
# Testing each novel edge for intron retention:  35%|███▌      | 421/1186 [42:18<1:15:17,  5.91s/it]
# Testing each novel edge for intron retention:  36%|███▌      | 422/1186 [42:24<1:17:07,  6.06s/it]
# Testing each novel edge for intron retention:  36%|███▌      | 423/1186 [42:30<1:16:05,  5.98s/it]
# Testing each novel edge for intron retention:  36%|███▌      | 424/1186 [42:36<1:17:32,  6.11s/it]
# Testing each novel edge for intron retention:  36%|███▌      | 425/1186 [42:42<1:16:06,  6.00s/it]
# Testing each novel edge for intron retention:  36%|███▌      | 426/1186 [42:48<1:17:16,  6.10s/it]
# Testing each novel edge for intron retention:  36%|███▌      | 427/1186 [42:54<1:15:43,  5.99s/it]
# Testing each novel edge for intron retention:  36%|███▌      | 428/1186 [43:00<1:17:03,  6.10s/it]
# Testing each novel edge for intron retention:  36%|███▌      | 429/1186 [43:06<1:15:46,  6.01s/it]
# Testing each novel edge for intron retention:  36%|███▋      | 430/1186 [43:12<1:14:49,  5.94s/it]
# Testing each novel edge for intron retention:  36%|███▋      | 431/1186 [43:18<1:16:23,  6.07s/it]
# Testing each novel edge for intron retention:  36%|███▋      | 432/1186 [43:24<1:15:20,  6.00s/it]
# Testing each novel edge for intron retention:  37%|███▋      | 433/1186 [43:31<1:16:37,  6.11s/it]
# Testing each novel edge for intron retention:  37%|███▋      | 434/1186 [43:36<1:15:24,  6.02s/it]
# Testing each novel edge for intron retention:  37%|███▋      | 435/1186 [43:43<1:16:34,  6.12s/it]
# Testing each novel edge for intron retention:  37%|███▋      | 436/1186 [43:49<1:15:20,  6.03s/it]
# Testing each novel edge for intron retention:  37%|███▋      | 437/1186 [43:54<1:14:16,  5.95s/it]
# Testing each novel edge for intron retention:  37%|███▋      | 438/1186 [44:01<1:15:53,  6.09s/it]
# Testing each novel edge for intron retention:  37%|███▋      | 439/1186 [44:07<1:14:51,  6.01s/it]
# Testing each novel edge for intron retention:  37%|███▋      | 440/1186 [44:12<1:13:56,  5.95s/it]
# Testing each novel edge for intron retention:  37%|███▋      | 441/1186 [44:18<1:13:03,  5.88s/it]
# Testing each novel edge for intron retention:  37%|███▋      | 442/1186 [44:25<1:15:25,  6.08s/it]
# Testing each novel edge for intron retention:  37%|███▋      | 443/1186 [44:30<1:13:56,  5.97s/it]
# Testing each novel edge for intron retention:  37%|███▋      | 444/1186 [44:37<1:15:20,  6.09s/it]
# Testing each novel edge for intron retention:  38%|███▊      | 445/1186 [44:43<1:14:08,  6.00s/it]
# Testing each novel edge for intron retention:  38%|███▊      | 446/1186 [44:49<1:15:28,  6.12s/it]
# Testing each novel edge for intron retention:  38%|███▊      | 447/1186 [44:55<1:14:01,  6.01s/it]
# Testing each novel edge for intron retention:  38%|███▊      | 448/1186 [45:01<1:15:28,  6.14s/it]
# Testing each novel edge for intron retention:  38%|███▊      | 449/1186 [45:07<1:14:06,  6.03s/it]
# Testing each novel edge for intron retention:  38%|███▊      | 450/1186 [45:13<1:13:10,  5.97s/it]
# Testing each novel edge for intron retention:  38%|███▊      | 451/1186 [45:19<1:14:38,  6.09s/it]
# Testing each novel edge for intron retention:  38%|███▊      | 452/1186 [45:25<1:13:31,  6.01s/it]
# Testing each novel edge for intron retention:  38%|███▊      | 453/1186 [45:31<1:12:33,  5.94s/it]
# Testing each novel edge for intron retention:  38%|███▊      | 454/1186 [45:37<1:14:14,  6.09s/it]
# Testing each novel edge for intron retention:  38%|███▊      | 455/1186 [45:43<1:13:08,  6.00s/it]
# Testing each novel edge for intron retention:  38%|███▊      | 456/1186 [45:49<1:12:06,  5.93s/it]
# Testing each novel edge for intron retention:  39%|███▊      | 457/1186 [45:54<1:11:26,  5.88s/it]
# Testing each novel edge for intron retention:  39%|███▊      | 458/1186 [46:01<1:12:55,  6.01s/it]
# Testing each novel edge for intron retention:  39%|███▊      | 459/1186 [46:07<1:12:41,  6.00s/it]
# Testing each novel edge for intron retention:  39%|███▉      | 460/1186 [46:13<1:13:43,  6.09s/it]
# Testing each novel edge for intron retention:  39%|███▉      | 461/1186 [46:19<1:12:28,  6.00s/it]
# Testing each novel edge for intron retention:  39%|███▉      | 462/1186 [46:25<1:13:32,  6.09s/it]
# Testing each novel edge for intron retention:  39%|███▉      | 463/1186 [46:31<1:12:14,  6.00s/it]
# Testing each novel edge for intron retention:  39%|███▉      | 464/1186 [46:37<1:11:41,  5.96s/it]
# Testing each novel edge for intron retention:  39%|███▉      | 465/1186 [46:43<1:13:16,  6.10s/it]
# Testing each novel edge for intron retention:  39%|███▉      | 466/1186 [46:49<1:11:58,  6.00s/it]
# Testing each novel edge for intron retention:  39%|███▉      | 467/1186 [46:55<1:13:16,  6.11s/it]
# Testing each novel edge for intron retention:  39%|███▉      | 468/1186 [47:01<1:12:03,  6.02s/it]
# Testing each novel edge for intron retention:  40%|███▉      | 469/1186 [47:07<1:11:06,  5.95s/it]
# Testing each novel edge for intron retention:  40%|███▉      | 470/1186 [47:13<1:12:22,  6.06s/it]
# Testing each novel edge for intron retention:  40%|███▉      | 471/1186 [47:19<1:11:22,  5.99s/it]
# Testing each novel edge for intron retention:  40%|███▉      | 472/1186 [47:25<1:10:45,  5.95s/it]
# Testing each novel edge for intron retention:  40%|███▉      | 473/1186 [47:31<1:12:07,  6.07s/it]
# Testing each novel edge for intron retention:  40%|███▉      | 474/1186 [47:37<1:11:08,  6.00s/it]
# Testing each novel edge for intron retention:  40%|████      | 475/1186 [47:43<1:10:16,  5.93s/it]
# Testing each novel edge for intron retention:  40%|████      | 476/1186 [47:49<1:11:41,  6.06s/it]
# Testing each novel edge for intron retention:  40%|████      | 477/1186 [47:55<1:10:42,  5.98s/it]
# Testing each novel edge for intron retention:  40%|████      | 478/1186 [48:01<1:09:41,  5.91s/it]
# Testing each novel edge for intron retention:  40%|████      | 479/1186 [48:07<1:11:21,  6.06s/it]
# Testing each novel edge for intron retention:  40%|████      | 480/1186 [48:13<1:10:04,  5.96s/it]
# Testing each novel edge for intron retention:  41%|████      | 481/1186 [48:19<1:11:35,  6.09s/it]
# Testing each novel edge for intron retention:  41%|████      | 482/1186 [48:25<1:10:26,  6.00s/it]
# Testing each novel edge for intron retention:  41%|████      | 483/1186 [48:31<1:09:30,  5.93s/it]
# ...
# Testing each novel edge for intron retention:  87%|████████▋ | 1028/1186 [1:43:23<15:39,  5.94s/it]
# Testing each novel edge for intron retention:  87%|████████▋ | 1029/1186 [1:43:29<15:51,  6.06s/it]
# Testing each novel edge for intron retention:  87%|████████▋ | 1030/1186 [1:43:35<15:35,  5.99s/it]
# Testing each novel edge for intron retention:  87%|████████▋ | 1031/1186 [1:43:41<15:23,  5.96s/it]
# Testing each novel edge for intron retention:  87%|████████▋ | 1032/1186 [1:43:46<15:08,  5.90s/it]
# Testing each novel edge for intron retention:  87%|████████▋ | 1033/1186 [1:43:53<15:23,  6.03s/it]
# Testing each novel edge for intron retention:  87%|████████▋ | 1034/1186 [1:43:59<15:12,  6.01s/it]
# Testing each novel edge for intron retention:  87%|████████▋ | 1035/1186 [1:44:05<15:21,  6.10s/it]
# Testing each novel edge for intron retention:  87%|████████▋ | 1036/1186 [1:44:11<15:07,  6.05s/it]
# Testing each novel edge for intron retention:  87%|████████▋ | 1037/1186 [1:44:17<15:18,  6.16s/it]
# Testing each novel edge for intron retention:  88%|████████▊ | 1038/1186 [1:44:23<14:52,  6.03s/it]
# Testing each novel edge for intron retention:  88%|████████▊ | 1039/1186 [1:44:29<14:33,  5.94s/it]
# Testing each novel edge for intron retention:  88%|████████▊ | 1040/1186 [1:44:35<14:45,  6.07s/it]
# Testing each novel edge for intron retention:  88%|████████▊ | 1041/1186 [1:44:41<14:30,  6.00s/it]
# Testing each novel edge for intron retention:  88%|████████▊ | 1042/1186 [1:44:47<14:44,  6.14s/it]
# Testing each novel edge for intron retention:  88%|████████▊ | 1043/1186 [1:44:53<14:20,  6.02s/it]
# Testing each novel edge for intron retention:  88%|████████▊ | 1044/1186 [1:44:59<14:02,  5.93s/it]
# Testing each novel edge for intron retention:  88%|████████▊ | 1045/1186 [1:45:05<14:14,  6.06s/it]
# Testing each novel edge for intron retention:  88%|████████▊ | 1046/1186 [1:45:11<13:57,  5.99s/it]
# Testing each novel edge for intron retention:  88%|████████▊ | 1047/1186 [1:45:17<13:46,  5.95s/it]
# Testing each novel edge for intron retention:  88%|████████▊ | 1048/1186 [1:45:23<13:55,  6.06s/it]
# Testing each novel edge for intron retention:  88%|████████▊ | 1049/1186 [1:45:29<13:38,  5.97s/it]
# Testing each novel edge for intron retention:  89%|████████▊ | 1050/1186 [1:45:35<13:24,  5.91s/it]
# Testing each novel edge for intron retention:  89%|████████▊ | 1051/1186 [1:45:41<13:41,  6.08s/it]
# Testing each novel edge for intron retention:  89%|████████▊ | 1052/1186 [1:45:47<13:21,  5.98s/it]
# Testing each novel edge for intron retention:  89%|████████▉ | 1053/1186 [1:45:53<13:09,  5.94s/it]
# Testing each novel edge for intron retention:  89%|████████▉ | 1054/1186 [1:45:59<13:21,  6.07s/it]
# Testing each novel edge for intron retention:  89%|████████▉ | 1055/1186 [1:46:05<13:03,  5.98s/it]
# Testing each novel edge for intron retention:  89%|████████▉ | 1056/1186 [1:46:11<13:13,  6.11s/it]
# Testing each novel edge for intron retention:  89%|████████▉ | 1057/1186 [1:46:17<12:54,  6.00s/it]
# Testing each novel edge for intron retention:  89%|████████▉ | 1058/1186 [1:46:23<12:39,  5.93s/it]
# Testing each novel edge for intron retention:  89%|████████▉ | 1059/1186 [1:46:29<12:27,  5.89s/it]
# Testing each novel edge for intron retention:  89%|████████▉ | 1060/1186 [1:46:35<12:45,  6.07s/it]
# Testing each novel edge for intron retention:  89%|████████▉ | 1061/1186 [1:46:41<12:28,  5.99s/it]
# Testing each novel edge for intron retention:  90%|████████▉ | 1062/1186 [1:46:48<12:43,  6.16s/it]
# Testing each novel edge for intron retention:  90%|████████▉ | 1063/1186 [1:46:53<12:21,  6.03s/it]
# Testing each novel edge for intron retention:  90%|████████▉ | 1064/1186 [1:47:00<12:27,  6.13s/it]
# Testing each novel edge for intron retention:  90%|████████▉ | 1065/1186 [1:47:05<12:08,  6.02s/it]
# Testing each novel edge for intron retention:  90%|████████▉ | 1066/1186 [1:47:12<12:16,  6.13s/it]
# Testing each novel edge for intron retention:  90%|████████▉ | 1067/1186 [1:47:18<11:56,  6.02s/it]
# Testing each novel edge for intron retention:  90%|█████████ | 1068/1186 [1:47:23<11:41,  5.94s/it]
# Testing each novel edge for intron retention:  90%|█████████ | 1069/1186 [1:47:30<11:51,  6.08s/it]
# Testing each novel edge for intron retention:  90%|█████████ | 1070/1186 [1:47:36<11:35,  6.00s/it]
# Testing each novel edge for intron retention:  90%|█████████ | 1071/1186 [1:47:41<11:23,  5.94s/it]
# Testing each novel edge for intron retention:  90%|█████████ | 1072/1186 [1:47:47<11:10,  5.88s/it]
# Testing each novel edge for intron retention:  90%|█████████ | 1073/1186 [1:47:53<11:20,  6.02s/it]
# Testing each novel edge for intron retention:  91%|█████████ | 1074/1186 [1:47:59<11:04,  5.93s/it]
# Testing each novel edge for intron retention:  91%|█████████ | 1075/1186 [1:48:06<11:13,  6.07s/it]
# Testing each novel edge for intron retention:  91%|█████████ | 1076/1186 [1:48:11<10:59,  5.99s/it]
# Testing each novel edge for intron retention:  91%|█████████ | 1077/1186 [1:48:18<11:05,  6.10s/it]
# Testing each novel edge for intron retention:  91%|█████████ | 1078/1186 [1:48:24<10:48,  6.00s/it]
# Testing each novel edge for intron retention:  91%|█████████ | 1079/1186 [1:48:29<10:34,  5.93s/it]
# Testing each novel edge for intron retention:  91%|█████████ | 1080/1186 [1:48:36<10:42,  6.06s/it]
# Testing each novel edge for intron retention:  91%|█████████ | 1081/1186 [1:48:41<10:28,  5.99s/it]
# Testing each novel edge for intron retention:  91%|█████████ | 1082/1186 [1:48:47<10:17,  5.94s/it]
# Testing each novel edge for intron retention:  91%|█████████▏| 1083/1186 [1:48:54<10:35,  6.17s/it]
# Testing each novel edge for intron retention:  91%|█████████▏| 1084/1186 [1:49:00<10:17,  6.06s/it]
# Testing each novel edge for intron retention:  91%|█████████▏| 1085/1186 [1:49:06<10:19,  6.13s/it]
# Testing each novel edge for intron retention:  92%|█████████▏| 1086/1186 [1:49:12<10:02,  6.02s/it]
# Testing each novel edge for intron retention:  92%|█████████▏| 1087/1186 [1:49:18<09:48,  5.95s/it]
# Testing each novel edge for intron retention:  92%|█████████▏| 1088/1186 [1:49:24<09:55,  6.08s/it]
# Testing each novel edge for intron retention:  92%|█████████▏| 1089/1186 [1:49:30<09:41,  5.99s/it]
# Testing each novel edge for intron retention:  92%|█████████▏| 1090/1186 [1:49:36<09:48,  6.13s/it]
# Testing each novel edge for intron retention:  92%|█████████▏| 1091/1186 [1:49:42<09:32,  6.03s/it]
# Testing each novel edge for intron retention:  92%|█████████▏| 1092/1186 [1:49:48<09:37,  6.15s/it]
# Testing each novel edge for intron retention:  92%|█████████▏| 1093/1186 [1:49:54<09:21,  6.04s/it]
# Testing each novel edge for intron retention:  92%|█████████▏| 1094/1186 [1:50:01<09:24,  6.14s/it]
# Testing each novel edge for intron retention:  92%|█████████▏| 1095/1186 [1:50:06<09:09,  6.04s/it]
# Testing each novel edge for intron retention:  92%|█████████▏| 1096/1186 [1:50:12<08:56,  5.96s/it]
# Testing each novel edge for intron retention:  92%|█████████▏| 1097/1186 [1:50:19<09:03,  6.11s/it]
# Testing each novel edge for intron retention:  93%|█████████▎| 1098/1186 [1:50:24<08:48,  6.01s/it]
# Testing each novel edge for intron retention:  93%|█████████▎| 1099/1186 [1:50:30<08:35,  5.93s/it]
# Testing each novel edge for intron retention:  93%|█████████▎| 1100/1186 [1:50:37<08:41,  6.07s/it]
# Testing each novel edge for intron retention:  93%|█████████▎| 1101/1186 [1:50:42<08:28,  5.98s/it]
# Testing each novel edge for intron retention:  93%|█████████▎| 1102/1186 [1:50:49<08:31,  6.09s/it]
# Testing each novel edge for intron retention:  93%|█████████▎| 1103/1186 [1:50:55<08:17,  5.99s/it]
# Testing each novel edge for intron retention:  93%|█████████▎| 1104/1186 [1:51:01<08:19,  6.10s/it]
# Testing each novel edge for intron retention:  93%|█████████▎| 1105/1186 [1:51:07<08:06,  6.01s/it]
# Testing each novel edge for intron retention:  93%|█████████▎| 1106/1186 [1:51:13<08:08,  6.11s/it]
# Testing each novel edge for intron retention:  93%|█████████▎| 1107/1186 [1:51:19<07:56,  6.03s/it]
# Testing each novel edge for intron retention:  93%|█████████▎| 1108/1186 [1:51:25<07:57,  6.12s/it]
# Testing each novel edge for intron retention:  94%|█████████▎| 1109/1186 [1:51:31<07:42,  6.01s/it]
# Testing each novel edge for intron retention:  94%|█████████▎| 1110/1186 [1:51:37<07:34,  5.98s/it]
# Testing each novel edge for intron retention:  94%|█████████▎| 1111/1186 [1:51:43<07:26,  5.95s/it]
# Testing each novel edge for intron retention:  94%|█████████▍| 1112/1186 [1:51:49<07:29,  6.08s/it]
# Testing each novel edge for intron retention:  94%|█████████▍| 1113/1186 [1:51:55<07:16,  5.98s/it]
# Testing each novel edge for intron retention:  94%|█████████▍| 1114/1186 [1:52:01<07:17,  6.08s/it]
# Testing each novel edge for intron retention:  94%|█████████▍| 1115/1186 [1:52:07<07:06,  6.01s/it]
# Testing each novel edge for intron retention:  94%|█████████▍| 1116/1186 [1:52:13<07:07,  6.11s/it]
# Testing each novel edge for intron retention:  94%|█████████▍| 1117/1186 [1:52:19<06:55,  6.03s/it]
# Testing each novel edge for intron retention:  94%|█████████▍| 1118/1186 [1:52:26<06:57,  6.14s/it]
# Testing each novel edge for intron retention:  94%|█████████▍| 1119/1186 [1:52:31<06:44,  6.03s/it]
# Testing each novel edge for intron retention:  94%|█████████▍| 1120/1186 [1:52:37<06:37,  6.02s/it]
# Testing each novel edge for intron retention:  95%|█████████▍| 1121/1186 [1:52:44<06:38,  6.14s/it]
# Testing each novel edge for intron retention:  95%|█████████▍| 1122/1186 [1:52:50<06:26,  6.04s/it]
# Testing each novel edge for intron retention:  95%|█████████▍| 1123/1186 [1:52:56<06:28,  6.16s/it]
# Testing each novel edge for intron retention:  95%|█████████▍| 1124/1186 [1:53:02<06:14,  6.04s/it]
# Testing each novel edge for intron retention:  95%|█████████▍| 1125/1186 [1:53:08<06:17,  6.18s/it]
# Testing each novel edge for intron retention:  95%|█████████▍| 1126/1186 [1:53:14<06:04,  6.07s/it]
# Testing each novel edge for intron retention:  95%|█████████▌| 1127/1186 [1:53:20<05:52,  5.98s/it]
# Testing each novel edge for intron retention:  95%|█████████▌| 1128/1186 [1:53:26<05:53,  6.10s/it]
# Testing each novel edge for intron retention:  95%|█████████▌| 1129/1186 [1:53:32<05:42,  6.02s/it]
# Testing each novel edge for intron retention:  95%|█████████▌| 1130/1186 [1:53:38<05:34,  5.97s/it]
# Testing each novel edge for intron retention:  95%|█████████▌| 1131/1186 [1:53:44<05:25,  5.92s/it]
# Testing each novel edge for intron retention:  95%|█████████▌| 1132/1186 [1:53:50<05:27,  6.06s/it]
# Testing each novel edge for intron retention:  96%|█████████▌| 1133/1186 [1:53:56<05:16,  5.96s/it]
# Testing each novel edge for intron retention:  96%|█████████▌| 1134/1186 [1:54:02<05:15,  6.08s/it]
# Testing each novel edge for intron retention:  96%|█████████▌| 1135/1186 [1:54:08<05:06,  6.00s/it]
# Testing each novel edge for intron retention:  96%|█████████▌| 1136/1186 [1:54:14<05:04,  6.08s/it]
# Testing each novel edge for intron retention:  96%|█████████▌| 1137/1186 [1:54:20<04:49,  5.90s/it]
# Testing each novel edge for intron retention:  96%|█████████▌| 1138/1186 [1:54:26<04:49,  6.04s/it]
# Testing each novel edge for intron retention:  96%|█████████▌| 1139/1186 [1:54:32<04:39,  5.95s/it]
# Testing each novel edge for intron retention:  96%|█████████▌| 1140/1186 [1:54:38<04:34,  5.96s/it]
# Testing each novel edge for intron retention:  96%|█████████▌| 1141/1186 [1:54:44<04:35,  6.13s/it]
# Testing each novel edge for intron retention:  96%|█████████▋| 1142/1186 [1:54:50<04:25,  6.03s/it]
# Testing each novel edge for intron retention:  96%|█████████▋| 1143/1186 [1:54:56<04:15,  5.94s/it]
# Testing each novel edge for intron retention:  96%|█████████▋| 1144/1186 [1:55:02<04:15,  6.08s/it]
# Testing each novel edge for intron retention:  97%|█████████▋| 1145/1186 [1:55:08<04:05,  5.99s/it]
# Testing each novel edge for intron retention:  97%|█████████▋| 1146/1186 [1:55:14<03:56,  5.91s/it]
# Testing each novel edge for intron retention:  97%|█████████▋| 1147/1186 [1:55:20<03:48,  5.86s/it]
# Testing each novel edge for intron retention:  97%|█████████▋| 1148/1186 [1:55:26<03:50,  6.05s/it]
# Testing each novel edge for intron retention:  97%|█████████▋| 1149/1186 [1:55:32<03:41,  5.99s/it]
# Testing each novel edge for intron retention:  97%|█████████▋| 1150/1186 [1:55:38<03:41,  6.14s/it]
# Testing each novel edge for intron retention:  97%|█████████▋| 1151/1186 [1:55:44<03:31,  6.04s/it]
# Testing each novel edge for intron retention:  97%|█████████▋| 1152/1186 [1:55:51<03:29,  6.15s/it]
# Testing each novel edge for intron retention:  97%|█████████▋| 1153/1186 [1:55:56<03:18,  6.03s/it]
# Testing each novel edge for intron retention:  97%|█████████▋| 1154/1186 [1:56:02<03:10,  5.96s/it]
# Testing each novel edge for intron retention:  97%|█████████▋| 1155/1186 [1:56:09<03:09,  6.11s/it]
# Testing each novel edge for intron retention:  97%|█████████▋| 1156/1186 [1:56:14<03:00,  6.00s/it]
# Testing each novel edge for intron retention:  98%|█████████▊| 1157/1186 [1:56:21<02:57,  6.11s/it]
# Testing each novel edge for intron retention:  98%|█████████▊| 1158/1186 [1:56:27<02:48,  6.02s/it]
# Testing each novel edge for intron retention:  98%|█████████▊| 1159/1186 [1:56:32<02:40,  5.96s/it]
# Testing each novel edge for intron retention:  98%|█████████▊| 1160/1186 [1:56:39<02:39,  6.12s/it]
# Testing each novel edge for intron retention:  98%|█████████▊| 1161/1186 [1:56:45<02:30,  6.02s/it]
# Testing each novel edge for intron retention:  98%|█████████▊| 1162/1186 [1:56:51<02:24,  6.01s/it]
# Testing each novel edge for intron retention:  98%|█████████▊| 1163/1186 [1:56:57<02:20,  6.12s/it]
# Testing each novel edge for intron retention:  98%|█████████▊| 1164/1186 [1:57:03<02:12,  6.01s/it]
# Testing each novel edge for intron retention:  98%|█████████▊| 1165/1186 [1:57:09<02:04,  5.94s/it]
# Testing each novel edge for intron retention:  98%|█████████▊| 1166/1186 [1:57:15<02:01,  6.06s/it]
# Testing each novel edge for intron retention:  98%|█████████▊| 1167/1186 [1:57:21<01:53,  5.97s/it]
# Testing each novel edge for intron retention:  98%|█████████▊| 1168/1186 [1:57:27<01:47,  5.95s/it]
# Testing each novel edge for intron retention:  99%|█████████▊| 1169/1186 [1:57:33<01:43,  6.07s/it]
# Testing each novel edge for intron retention:  99%|█████████▊| 1170/1186 [1:57:39<01:36,  6.02s/it]
# Testing each novel edge for intron retention:  99%|█████████▊| 1171/1186 [1:57:45<01:32,  6.16s/it]
# Testing each novel edge for intron retention:  99%|█████████▉| 1172/1186 [1:57:51<01:24,  6.06s/it]
# Testing each novel edge for intron retention:  99%|█████████▉| 1173/1186 [1:57:57<01:18,  6.00s/it]
# Testing each novel edge for intron retention:  99%|█████████▉| 1174/1186 [1:58:03<01:11,  5.97s/it]
# Testing each novel edge for intron retention:  99%|█████████▉| 1175/1186 [1:58:09<01:07,  6.14s/it]
# Testing each novel edge for intron retention:  99%|█████████▉| 1176/1186 [1:58:15<01:00,  6.06s/it]
# Testing each novel edge for intron retention:  99%|█████████▉| 1177/1186 [1:58:22<00:55,  6.16s/it]
# Testing each novel edge for intron retention:  99%|█████████▉| 1178/1186 [1:58:27<00:48,  6.04s/it]
# Testing each novel edge for intron retention:  99%|█████████▉| 1179/1186 [1:58:34<00:42,  6.13s/it]
# Testing each novel edge for intron retention:  99%|█████████▉| 1180/1186 [1:58:40<00:36,  6.06s/it]
# Testing each novel edge for intron retention: 100%|█████████▉| 1181/1186 [1:58:46<00:30,  6.20s/it]
# Testing each novel edge for intron retention: 100%|█████████▉| 1182/1186 [1:58:52<00:24,  6.09s/it]
# Testing each novel edge for intron retention: 100%|█████████▉| 1183/1186 [1:58:58<00:17,  5.99s/it]
# Testing each novel edge for intron retention: 100%|█████████▉| 1184/1186 [1:59:04<00:12,  6.12s/it]
# Testing each novel edge for intron retention: 100%|█████████▉| 1185/1186 [1:59:10<00:06,  6.03s/it]
# Testing each novel edge for intron retention: 100%|██████████| 1186/1186 [1:59:16<00:00,  5.97s/it]
# Found 35 novel ir events in 27 transcripts.

# %% [markdown]
# You can pass gene IDs from `es_df` into `gen_report()` or `plot_graph()` to visualize where these exon-skipping events are in gene reports or gene summary graphs respectively.
